# %% [markdown]
# # Probelm overview
#
# The problem refers, as demonstrated at index, "to the city-cycle fuel consumption in miles per gallon". It contains five continuous variables and 3 discretes. Throughout the course of this assignment, it will be worked only the continuous ones. In the Linear Regression, the attribute "mpg"(miles per galon) will act as the dependent variable "y" while the others as independents.

# %% [markdown]
# # Importing Modules and the Dataset

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('output.csv')
print(df)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0        86.0  2790.0          15.6
# 388  44.0          4          97.0        52.0  2130.0          24.6
# 389  32.0          4         135.0        84.0  2295.0          11.6
# 390  28.0          4         120.0        79.0  2625.0          18.6
# 391  31.0          4         119.0        82.0  2720.0          19.4
#
#      modelyear  origin                     car name
# 0           70       1  "chevrolet chevelle malibu"
# ...

# %% [markdown]
# # Data Analysis

# %%
n_registers = df.shape[0]
print('Number of Registers:', n_registers)
n_variables = df.shape[1]
print('Number of Variables:', n_variables)
# Out:
# Number of Registers: 392
# Number of Variables: 9

# %%
#The occurencies of empty values in the given dataset is marked with '?'

empty_value = '?'
res = 0
for column in df.columns:
    occurrences = df[column].value_counts().get(empty_value, 0)
    res += occurrences

print('Number of empty values:', res )
# Out:
# Number of empty values: 0

# %%
for column in df.columns[:-1]:
    print('============',column, '============')
    print('Min value: ', df[column].min())
    print('Max value: ', df[column].max())
    print('Mean value: ', df[column].mean())
    print('Std deviation value: ', df[column].std())
    print('Variance value: ', df[column].var())
    print('============', column, '============\n')
# Out:
# ============ mpg ============
# Min value:  9.0
# Max value:  46.6
# Mean value:  23.445918367346938
# Std deviation value:  7.8050074865717995
# Variance value:  60.91814186544184
# ============ mpg ============
#
# ============ cylinders ============
# Min value:  3
# Max value:  8
# Mean value:  5.471938775510204
# Std deviation value:  1.7057832474527845
# Variance value:  2.9096964872905677
# ============ cylinders ============
#
# ============ displacement ============
# Min value:  68.0
# Max value:  455.0
# Mean value:  194.41198979591837
# Std deviation value:  104.64400390890466
# Variance value:  10950.367554086853
# ============ displacement ============
#
# ============ horsepower ============
# Min value:  46.0
# Max value:  230.0
# Mean value:  104.46938775510205
# Std deviation value:  38.49115993282849
# Variance value:  1481.5693929745814
# ============ horsepower ============
#
# ============ weight ============
# Min value:  1613.0
# Max value:  5140.0
# ...

# %%
for column in df.columns[:-1]:
    sns.histplot(data=df, x=column)
    plt.show()

# %%
sns.displot(data=df, x="mpg", kde=True)
# Out:
# /home/unknown/.local/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Principal Components Analysis

X = df.drop('car name', axis=1)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA()
pca.fit(X_scaled)

explained_variance_ratio = pca.explained_variance_ratio_
principal_components = pca.components_

print("Explained Variance Ratio:", explained_variance_ratio)
print("Principal Components:", principal_components)
# Out:
# Explained Variance Ratio: [0.67198404 0.11795791 0.10145546 0.06076949 0.02285332 0.01429024
#  0.00669335 0.00399619]
# Principal Components: [[-0.38586239  0.4023885   0.41644435  0.40183594  0.40157579 -0.2647309
#   -0.21386777 -0.27786815]
#  [-0.07663269 -0.13842878 -0.12632499  0.11148007 -0.21102    -0.41690206
#   -0.6904632   0.50150064]
#  [-0.29228579 -0.07223935 -0.07423622 -0.23605571  0.00089399  0.63943514
#   -0.5871892  -0.30732382]
#  [-0.09998251  0.21603551  0.13581398  0.11971643  0.32246785  0.49280794
#    0.10601968  0.74328281]
#  [-0.74036644 -0.48261485 -0.30331627  0.08426839  0.13127292 -0.09773197
#    0.30134385  0.04739508]
#  [ 0.38735165 -0.53092548 -0.00699705  0.6667096   0.23585961  0.20293343
#   -0.11002592 -0.12086663]
#  [-0.19588516  0.27878265 -0.08422855  0.53504996 -0.72202073  0.22891382
#    0.12501506 -0.0345266 ]
#  [-0.1151321  -0.41774679  0.82916553 -0.13477548 -0.30991105  0.03518826
#    0.0542884   0.07951102]]
